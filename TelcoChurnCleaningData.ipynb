# %%
import pandas as pd

# Load the dataset
file_path = 'Telco_customer_churn.csv'
telco_data = pd.read_csv(file_path)

# Displaying the first few rows of the dataset to understand its structure
telco_data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
def convert_binary_columns(df, exclude_column='Gender'):
    for column in df.columns:
        if column != exclude_column:
            unique_values = df[column].unique()
            if len(unique_values) == 2:
                df[column] = df[column].map({unique_values[0]: 0, unique_values[1]: 1})
    return df


telco_data_binary_converted = convert_binary_columns(telco_data)

# %%
# Converting 'Total Charges' from object to numeric
# First, we need to handle non-numeric values, if any, by converting them to NaN
telco_data['Total Charges'] = pd.to_numeric(telco_data['Total Charges'], errors='coerce')

# Checking for new missing values in 'Total Charges'
new_missing_values = telco_data['Total Charges'].isnull().sum()
new_missing_values
# Out:
# 11

# %%
# Examining rows with missing 'Total Charges'
missing_total_charges_rows = telco_data[data['Total Charges'].isnull()]
missing_total_charges_rows

# %%
# Filling missing 'Total Charges' with 0
telco_data['Total Charges'].fillna(0, inplace=True)

# Confirming the changes
missing_values_after_filling = telco_data['Total Charges'].isnull().sum()
missing_values_after_filling
# Out:
# 0
